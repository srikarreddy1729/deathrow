# %% [markdown]
# This notebook is based on the Andrew Karpathy's [NanoGPT](https://colab.research.google.com/drive/1JMLa53HDuA-i7ZBmqV7ZnA3c_fvtXnx-?usp=sharing) tutorial.
#
# I have extracted text from a [csv file](https://www.kaggle.com/datasets/samerhijjazi/death-row-inmates-last-statements-texas-2020) availabe on kaggle.

# %%
# this code is used to extract last statement in txt format
# from the csv file available on kaggle 

import csv

# Read the CSV file

with open('deathrow.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)

    # Get the column you want to extract
    column_to_extract = [row[8] for row in reader]

    # Create a new text file
    with open('deathrow_statement.txt', 'w') as textfile:
        for item in column_to_extract:
            if item != "decline":
                textfile.write(item + '\n\n')

# Close the files
csvfile.close()
textfile.close()

# %%
#the deathrow_statement file contains the text from last statements of Texas deathrow inmates

# !wget https://raw.githubusercontent.com/srikarreddy1729/deathrow/main/deathrow_statement.txt
# Out:
# --2023-05-16 15:30:20--  https://raw.githubusercontent.com/srikarreddy1729/deathrow/main/deathrow_statement.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244295 (239K) [text/plain]
# Saving to: ‘deathrow_statement.txt’
#
# deathrow_statement. 100%[===================>] 238.57K  --.-KB/s    in 0.03s
#
# 2023-05-16 15:30:20 (8.77 MB/s) - ‘deathrow_statement.txt’ saved [244295/244295]

# %%
# read it in to inspect it
with open('deathrow_statement.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
print("length of dataset in characters: ", len(text))
# Out:
# length of dataset in characters:  244128

# %%
# let's look at the first 1000 characters
print(text[:1000])
# Out:
# Last Statement
#
# Yes sir. I  would like to thank God, my dad, my Lord Jesus savior for saving me and changing  my life. I want to apologize to my in-laws for causing all this emotional pain.  I love y'all and consider y'all my sisters I never had. I want to thank you for  forgiving me. Thank you warden. ,
#
# Thank you thank you  where's the family, ok I would like to say sorry for the grief I have caused. I  hope you find peace, joy and closure. Whatever it takes to forgive me. I am  sorry. I know you cannot forgive me but I hope one day you will. To my friends,  I love ya'll. You have been good and such good influence people. I want to see  the Lord Jesus so bad. I hope you all understand. I am going to ask the Warden  to start. And ask Jesus to help them to forgive me one day please. I am very  sorry. For you guys I love you. Thank you Warden.
#
# Yeah, I want to  address the Roundtree family and apologize for the pain and suffering I caused.  And to the Diaz's family that I had to put you

# %%
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#  !"#&'()+,-./0123456789:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz ¦½
# 87

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

print(encode("my love"))
print(decode(encode("my love")))
# Out:
# [65, 77, 1, 64, 67, 74, 57]
# my love

# %%
# let's now encode the entire text dataset and store it into a torch.Tensor
import torch # we use PyTorch: https://pytorch.org
data = torch.tensor(encode(text), dtype=torch.long)
print(data.shape, data.dtype)
print(data[:1000]) # the 1000 characters we looked at earier will to the GPT look like this
# Out:
# torch.Size([244128]) torch.int64
# tensor([38, 53, 71, 72,  1, 45, 72, 53, 72, 57, 65, 57, 66, 72,  0,  0, 51, 57,
#         71,  1, 71, 61, 70, 12,  1, 35,  1,  1, 75, 67, 73, 64, 56,  1, 64, 61,
#         63, 57,  1, 72, 67,  1, 72, 60, 53, 66, 63,  1, 33, 67, 56, 10,  1, 65,
#         77,  1, 56, 53, 56, 10,  1, 65, 77,  1, 38, 67, 70, 56,  1, 36, 57, 71,
#         73, 71,  1, 71, 53, 74, 61, 67, 70,  1, 58, 67, 70,  1, 71, 53, 74, 61,
#         66, 59,  1, 65, 57,  1, 53, 66, 56,  1, 55, 60, 53, 66, 59, 61, 66, 59,
#          1,  1, 65, 77,  1, 64, 61, 58, 57, 12,  1, 35,  1, 75, 53, 66, 72,  1,
#         72, 67,  1, 53, 68, 67, 64, 67, 59, 61, 78, 57,  1, 72, 67,  1, 65, 77,
#          1, 61, 66, 11, 64, 53, 75, 71,  1, 58, 67, 70,  1, 55, 53, 73, 71, 61,
#         66, 59,  1, 53, 64, 64,  1, 72, 60, 61, 71,  1, 57, 65, 67, 72, 61, 67,
#         66, 53, 64,  1, 68, 53, 61, 66, 12,  1,  1, 35,  1, 64, 67, 74, 57,  1,
#         77,  6, 53, 64, 64,  1, 53, 66, 56,  1, 55, 67, 66, 71, 61, 56, 57, 70,
#          1, 77,  6, 53, 64, 64,  1, 65, 77,  1, 71, 61, 71, 72, 57, 70, 71,  1,
#         35,  1, 66, 57, 74, 57, 70,  1, 60, 53, 56, 12,  1, 35,  1, 75, 53, 66,
#         72,  1, 72, 67,  1, 72, 60, 53, 66, 63,  1, 77, 67, 73,  1, 58, 67, 70,
#          1,  1, 58, 67, 70, 59, 61, 74, 61, 66, 59,  1, 65, 57, 12,  1, 46, 60,
#         53, 66, 63,  1, 77, 67, 73,  1, 75, 53, 70, 56, 57, 66, 12,  1, 10,  0,
#          0, 46, 60, 53, 66, 63,  1, 77, 67, 73,  1, 72, 60, 53, 66, 63,  1, 77,
#         67, 73,  1,  1, 75, 60, 57, 70, 57,  6, 71,  1, 72, 60, 57,  1, 58, 53,
#         65, 61, 64, 77, 10,  1, 67, 63,  1, 35,  1, 75, 67, 73, 64, 56,  1, 64,
#         61, 63, 57,  1, 72, 67,  1, 71, 53, 77,  1, 71, 67, 70, 70, 77,  1, 58,
#         67, 70,  1, 72, 60, 57,  1, 59, 70, 61, 57, 58,  1, 35,  1, 60, 53, 74,
#         57,  1, 55, 53, 73, 71, 57, 56, 12,  1, 35,  1,  1, 60, 67, 68, 57,  1,
#         77, 67, 73,  1, 58, 61, 66, 56,  1, 68, 57, 53, 55, 57, 10,  1, 62, 67,
#         77,  1, 53, 66, 56,  1, 55, 64, 67, 71, 73, 70, 57, 12,  1, 49, 60, 53,
#         72, 57, 74, 57, 70,  1, 61, 72,  1, 72, 53, 63, 57, 71,  1, 72, 67,  1,
#         58, 67, 70, 59, 61, 74, 57,  1, 65, 57, 12,  1, 35,  1, 53, 65,  1,  1,
#         71, 67, 70, 70, 77, 12,  1, 35,  1, 63, 66, 67, 75,  1, 77, 67, 73,  1,
#         55, 53, 66, 66, 67, 72,  1, 58, 67, 70, 59, 61, 74, 57,  1, 65, 57,  1,
#         54, 73, 72,  1, 35,  1, 60, 67, 68, 57,  1, 67, 66, 57,  1, 56, 53, 77,
#          1, 77, 67, 73,  1, 75, 61, 64, 64, 12,  1, 46, 67,  1, 65, 77,  1, 58,
#         70, 61, 57, 66, 56, 71, 10,  1,  1, 35,  1, 64, 67, 74, 57,  1, 77, 53,
#          6, 64, 64, 12,  1, 51, 67, 73,  1, 60, 53, 74, 57,  1, 54, 57, 57, 66,
#          1, 59, 67, 67, 56,  1, 53, 66, 56,  1, 71, 73, 55, 60,  1, 59, 67, 67,
#         56,  1, 61, 66, 58, 64, 73, 57, 66, 55, 57,  1, 68, 57, 67, 68, 64, 57,
#         12,  1, 35,  1, 75, 53, 66, 72,  1, 72, 67,  1, 71, 57, 57,  1,  1, 72,
#         60, 57,  1, 38, 67, 70, 56,  1, 36, 57, 71, 73, 71,  1, 71, 67,  1, 54,
#         53, 56, 12,  1, 35,  1, 60, 67, 68, 57,  1, 77, 67, 73,  1, 53, 64, 64,
#          1, 73, 66, 56, 57, 70, 71, 72, 53, 66, 56, 12,  1, 35,  1, 53, 65,  1,
#         59, 67, 61, 66, 59,  1, 72, 67,  1, 53, 71, 63,  1, 72, 60, 57,  1, 49,
#         53, 70, 56, 57, 66,  1,  1, 72, 67,  1, 71, 72, 53, 70, 72, 12,  1, 27,
#         66, 56,  1, 53, 71, 63,  1, 36, 57, 71, 73, 71,  1, 72, 67,  1, 60, 57,
#         64, 68,  1, 72, 60, 57, 65,  1, 72, 67,  1, 58, 67, 70, 59, 61, 74, 57,
#          1, 65, 57,  1, 67, 66, 57,  1, 56, 53, 77,  1, 68, 64, 57, 53, 71, 57,
#         12,  1, 35,  1, 53, 65,  1, 74, 57, 70, 77,  1,  1, 71, 67, 70, 70, 77,
#         12,  1, 32, 67, 70,  1, 77, 67, 73,  1, 59, 73, 77, 71,  1, 35,  1, 64,
#         67, 74, 57,  1, 77, 67, 73, 12,  1, 46, 60, 53, 66, 63,  1, 77, 67, 73,
#          1, 49, 53, 70, 56, 57, 66, 12,  0,  0, 51, 57, 53, 60, 10,  1, 35,  1,
#         75, 53, 66, 72,  1, 72, 67,  1,  1, 53, 56, 56, 70, 57, 71, 71,  1, 72,
#         60, 57,  1, 44, 67, 73, 66, 56, 72, 70, 57, 57,  1, 58, 53, 65, 61, 64,
#         77,  1, 53, 66, 56,  1, 53, 68, 67, 64, 67, 59, 61, 78, 57,  1, 58, 67,
#         70,  1, 72, 60, 57,  1, 68, 53, 61, 66,  1, 53, 66, 56,  1, 71, 73, 58,
#         58, 57, 70, 61, 66, 59,  1, 35,  1, 55, 53, 73, 71, 57, 56, 12,  1,  1,
#         27, 66, 56,  1, 72, 67,  1, 72, 60, 57,  1, 30, 61, 53, 78,  6, 71,  1,
#         58, 53, 65, 61, 64, 77,  1, 72, 60, 53, 72,  1, 35,  1, 60, 53, 56,  1,
#         72, 67,  1, 68, 73, 72,  1, 77, 67, 73])

# %%
# Let's now split up the data into train and validation sets
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %%
block_size = 8
train_data[:block_size+1]
# Out:
# tensor([38, 53, 71, 72,  1, 45, 72, 53, 72])

# %%
x = train_data[:block_size]
y = train_data[1:block_size+1]
for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print(f"when input is {context} the target: {target}")
# Out:
# when input is tensor([38]) the target: 53
# when input is tensor([38, 53]) the target: 71
# when input is tensor([38, 53, 71]) the target: 72
# when input is tensor([38, 53, 71, 72]) the target: 1
# when input is tensor([38, 53, 71, 72,  1]) the target: 45
# when input is tensor([38, 53, 71, 72,  1, 45]) the target: 72
# when input is tensor([38, 53, 71, 72,  1, 45, 72]) the target: 53
# when input is tensor([38, 53, 71, 72,  1, 45, 72, 53]) the target: 72

# %%
torch.manual_seed(1337)
batch_size = 4 # how many independent sequences will we process in parallel?
block_size = 8 # what is the maximum context length for predictions?

def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    return x, y

xb, yb = get_batch('train')
print('inputs:')
print(xb.shape)
print(xb)
print('targets:')
print(yb.shape)
print(yb)

print('----')

for b in range(batch_size): # batch dimension
    for t in range(block_size): # time dimension
        context = xb[b, :t+1]
        target = yb[b,t]
        print(f"when input is {context.tolist()} the target: {target}")
# Out:
# inputs:
# torch.Size([4, 8])
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54]])
# targets:
# torch.Size([4, 8])
# tensor([[43, 58,  5, 57,  1, 46, 43, 39],
#         [53, 56,  1, 58, 46, 39, 58,  1],
#         [58,  1, 58, 46, 39, 58,  1, 46],
#         [17, 27, 10,  0, 21,  1, 54, 39]])
# ----
# when input is [24] the target: 43
# when input is [24, 43] the target: 58
# when input is [24, 43, 58] the target: 5
# when input is [24, 43, 58, 5] the target: 57
# when input is [24, 43, 58, 5, 57] the target: 1
# when input is [24, 43, 58, 5, 57, 1] the target: 46
# when input is [24, 43, 58, 5, 57, 1, 46] the target: 43
# when input is [24, 43, 58, 5, 57, 1, 46, 43] the target: 39
# when input is [44] the target: 53
# when input is [44, 53] the target: 56
# when input is [44, 53, 56] the target: 1
# when input is [44, 53, 56, 1] the target: 58
# when input is [44, 53, 56, 1, 58] the target: 46
# when input is [44, 53, 56, 1, 58, 46] the target: 39
# when input is [44, 53, 56, 1, 58, 46, 39] the target: 58
# when input is [44, 53, 56, 1, 58, 46, 39, 58] the target: 1
# when input is [52] the target: 58
# when input is [52, 58] the target: 1
# when input is [52, 58, 1] the target: 58
# when input is [52, 58, 1, 58] the target: 46
# when input is [52, 58, 1, 58, 46] the target: 39
# when input is [52, 58, 1, 58, 46, 39] the target: 58
# when input is [52, 58, 1, 58, 46, 39, 58] the target: 1
# when input is [52, 58, 1, 58, 46, 39, 58, 1] the target: 46
# when input is [25] the target: 17
# when input is [25, 17] the target: 27
# when input is [25, 17, 27] the target: 10
# when input is [25, 17, 27, 10] the target: 0
# when input is [25, 17, 27, 10, 0] the target: 21
# when input is [25, 17, 27, 10, 0, 21] the target: 1
# when input is [25, 17, 27, 10, 0, 21, 1] the target: 54
# when input is [25, 17, 27, 10, 0, 21, 1, 54] the target: 39

# %%
print(xb) # our input to the transformer
# Out:
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54]])

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# wgethttps://raw.githubusercontent.com/srikarreddy1729/deathrow/main/deathrow_statement.txt
with open('deathrow_statement.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.212567 M parameters
# step 0: train loss 4.6502, val loss 4.6615
# step 100: train loss 2.5123, val loss 2.5524
# step 200: train loss 2.3591, val loss 2.4102
# step 300: train loss 2.2358, val loss 2.2868
# step 400: train loss 2.1286, val loss 2.1961
# step 500: train loss 2.0193, val loss 2.0988
# step 600: train loss 1.9211, val loss 2.0254
# step 700: train loss 1.8906, val loss 1.9546
# step 800: train loss 1.8165, val loss 1.9070
# step 900: train loss 1.7729, val loss 1.8708
# step 1000: train loss 1.7432, val loss 1.8491
# step 1100: train loss 1.7020, val loss 1.7952
# step 1200: train loss 1.6749, val loss 1.7851
# step 1300: train loss 1.6491, val loss 1.7462
# step 1400: train loss 1.6276, val loss 1.7293
# step 1500: train loss 1.6110, val loss 1.7183
# step 1600: train loss 1.5887, val loss 1.7039
# step 1700: train loss 1.5661, val loss 1.6739
# step 1800: train loss 1.5614, val loss 1.6555
# step 1900: train loss 1.5290, val loss 1.6323
# step 2000: train loss 1.5346, val loss 1.6285
# step 2100: train loss 1.4870, val loss 1.6101
# step 2200: train loss 1.4799, val loss 1.5977
# step 2300: train loss 1.4891, val loss 1.6051
# step 2400: train loss 1.4665, val loss 1.5872
# step 2500: train loss 1.4563, val loss 1.5867
# step 2600: train loss 1.4462, val loss 1.5656
# step 2700: train loss 1.4362, val loss 1.5614
# step 2800: train loss 1.4224, val loss 1.5487
# step 2900: train loss 1.4354, val loss 1.5670
# step 3000: train loss 1.4156, val loss 1.5512
# step 3100: train loss 1.4055, val loss 1.5472
# step 3200: train loss 1.4050, val loss 1.5319
# step 3300: train loss 1.4018, val loss 1.5271
# step 3400: train loss 1.3833, val loss 1.5353
# step 3500: train loss 1.3796, val loss 1.5035
# step 3600: train loss 1.3837, val loss 1.5273
# step 3700: train loss 1.3521, val loss 1.5073
# step 3800: train loss 1.3490, val loss 1.5068
# step 3900: train loss 1.3552, val loss 1.4933
# step 4000: train loss 1.3575, val loss 1.5125
# step 4100: train loss 1.3392, val loss 1.4960
# step 4200: train loss 1.3346, val loss 1.4944
# step 4300: train loss 1.3252, val loss 1.4858
# step 4400: train loss 1.3213, val loss 1.4837
# step 4500: train loss 1.3254, val loss 1.4938
# step 4600: train loss 1.3190, val loss 1.4893
# step 4700: train loss 1.3212, val loss 1.5056
# step 4800: train loss 1.3030, val loss 1.4690
# step 4900: train loss 1.3086, val loss 1.4733
# step 4999: train loss 1.2963, val loss 1.4902
#
# Yes, I want to talk to my mon you at and nothing only   to he iturn head y'all up that is hose me of my've forgive me exiqust.  Sead I vene with I can got and sufficeful, and I love you, tworry my faggers. Jamement.
#
# Yes, I wouldn't me greath me buwhy Ms. Thappenaly art stop ast real, and I love ya'll. Thercial. I love you, My forgunish man you all the,son, but del come this is beed.  It all on everybody you can too!; I ase ye've forgiveness, Heylved todm been Patth. Guers for partion. Kout family, brief chance, my family and story.
#
# Helveds and thanks mempaine know what. I'm turdime. I love you all.
#
# Yes, sireby I thank the for what I love themss used things you chances and glosi't.. Life deself the wifers and the help If its you pecape it., Now no the nexas medrious, you can, Mrs. If tell you man's no forgive me. And I wisch was over you are.  I am sorry. (My Folughers I slove my dud her onl the days of You. , Dine my hearts their going tone.  It hope that Press. Thank you maiss you todFighty throughs this not world lides to me, I can't con invicary this derugumed ones on of the stoud for it only here that I'm gonna shormefully die, senced to you amporty.  Be exass Viverarenes:.
#
# If I love all of you close. I don.
#
# Yes, Bus ah, them someone being forsea, I want to say someone make to believes. He help them grand than he tobelumes of my hew names sure ondract Irengle to my bitted me with as us family to forget: I could for me. ,(love I'm soon thank you all offoriends I am sorry.  I hard ask Chaphd I cay. This is when. If you been I just. Momm from my life, I'll bessire. Thy love turget.  I know, I could know you I lay. Moud for aremplessingnst your lifes Lo-dera. Wardgen a this has one? I alpong have todays, What has she is remorent.  It is alloces of loved alf.  I love y'all. I am ready. I'm reed to the memother no help. Cannot, but y'all beran yours.  And I gonna keep as family.  Foster, and I love done to all¦, my be Bothrough those record. We inclosusete not he

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/srikarreddy1729/deathrow/main/deathrow_statement.txt

with open('deathrow_statement.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.212567 M parameters
# step 0: train loss 4.6502, val loss 4.6615
# step 100: train loss 2.5123, val loss 2.5524
# step 200: train loss 2.3591, val loss 2.4102
# step 300: train loss 2.2358, val loss 2.2868
# step 400: train loss 2.1286, val loss 2.1961
# step 500: train loss 2.0193, val loss 2.0988
# step 600: train loss 1.9211, val loss 2.0254
# step 700: train loss 1.8906, val loss 1.9546
# step 800: train loss 1.8165, val loss 1.9070
# step 900: train loss 1.7729, val loss 1.8708
# step 1000: train loss 1.7432, val loss 1.8491
# step 1100: train loss 1.7020, val loss 1.7952
# step 1200: train loss 1.6749, val loss 1.7851
# step 1300: train loss 1.6491, val loss 1.7462
# step 1400: train loss 1.6276, val loss 1.7293
# step 1500: train loss 1.6110, val loss 1.7183
# step 1600: train loss 1.5887, val loss 1.7039
# step 1700: train loss 1.5661, val loss 1.6739
# step 1800: train loss 1.5614, val loss 1.6555
# step 1900: train loss 1.5290, val loss 1.6323
# step 2000: train loss 1.5346, val loss 1.6285
# step 2100: train loss 1.4870, val loss 1.6101
# step 2200: train loss 1.4799, val loss 1.5977
# step 2300: train loss 1.4891, val loss 1.6051
# step 2400: train loss 1.4665, val loss 1.5872
# step 2500: train loss 1.4563, val loss 1.5867
# step 2600: train loss 1.4462, val loss 1.5656
# step 2700: train loss 1.4362, val loss 1.5614
# step 2800: train loss 1.4224, val loss 1.5487
# step 2900: train loss 1.4354, val loss 1.5670
# step 3000: train loss 1.4156, val loss 1.5512
# step 3100: train loss 1.4055, val loss 1.5472
# step 3200: train loss 1.4050, val loss 1.5319
# step 3300: train loss 1.4018, val loss 1.5271
# step 3400: train loss 1.3833, val loss 1.5353
# step 3500: train loss 1.3796, val loss 1.5035
# step 3600: train loss 1.3837, val loss 1.5273
# step 3700: train loss 1.3521, val loss 1.5073
# step 3800: train loss 1.3490, val loss 1.5068
# step 3900: train loss 1.3552, val loss 1.4933
# step 4000: train loss 1.3575, val loss 1.5125
# step 4100: train loss 1.3392, val loss 1.4960
# step 4200: train loss 1.3346, val loss 1.4944
# step 4300: train loss 1.3252, val loss 1.4858
# step 4400: train loss 1.3213, val loss 1.4837
# step 4500: train loss 1.3254, val loss 1.4938
# step 4600: train loss 1.3190, val loss 1.4893
# step 4700: train loss 1.3212, val loss 1.5056
# step 4800: train loss 1.3030, val loss 1.4690
# step 4900: train loss 1.3086, val loss 1.4733
# step 5000: train loss 1.2965, val loss 1.4917
# step 5100: train loss 1.2996, val loss 1.4876
# step 5200: train loss 1.3025, val loss 1.4730
# step 5300: train loss 1.2864, val loss 1.4717
# step 5400: train loss 1.2787, val loss 1.4588
# step 5500: train loss 1.2798, val loss 1.4566
# step 5600: train loss 1.2775, val loss 1.4605
# step 5700: train loss 1.2669, val loss 1.4525
# step 5800: train loss 1.2677, val loss 1.4680
# step 5900: train loss 1.2647, val loss 1.4391
# step 6000: train loss 1.2752, val loss 1.4668
# step 6100: train loss 1.2657, val loss 1.4536
# step 6200: train loss 1.2602, val loss 1.4732
# step 6300: train loss 1.2466, val loss 1.4647
# step 6400: train loss 1.2432, val loss 1.4672
# step 6500: train loss 1.2500, val loss 1.4580
# step 6600: train loss 1.2539, val loss 1.4545
# step 6700: train loss 1.2440, val loss 1.4372
# step 6800: train loss 1.2388, val loss 1.4661
# step 6900: train loss 1.2491, val loss 1.4428
# step 7000: train loss 1.2364, val loss 1.4582
# step 7100: train loss 1.2469, val loss 1.4709
# step 7200: train loss 1.2339, val loss 1.4470
# step 7300: train loss 1.2392, val loss 1.4761
# step 7400: train loss 1.2245, val loss 1.4330
# step 7500: train loss 1.2318, val loss 1.4331
# step 7600: train loss 1.2130, val loss 1.4239
# step 7700: train loss 1.2257, val loss 1.4567
# step 7800: train loss 1.2206, val loss 1.4421
# step 7900: train loss 1.2068, val loss 1.4338
# step 8000: train loss 1.2231, val loss 1.4333
# step 8100: train loss 1.2133, val loss 1.4467
# step 8200: train loss 1.2134, val loss 1.4422
# step 8300: train loss 1.2073, val loss 1.4369
# step 8400: train loss 1.2027, val loss 1.4350
# step 8500: train loss 1.1948, val loss 1.4454
# step 8600: train loss 1.1954, val loss 1.4310
# step 8700: train loss 1.1984, val loss 1.4176
# step 8800: train loss 1.1944, val loss 1.4263
# step 8900: train loss 1.1961, val loss 1.4308
# step 9000: train loss 1.2008, val loss 1.4444
# step 9100: train loss 1.1944, val loss 1.4221
# step 9200: train loss 1.1872, val loss 1.4362
# step 9300: train loss 1.1963, val loss 1.4197
# step 9400: train loss 1.1801, val loss 1.4325
# step 9500: train loss 1.1817, val loss 1.4314
# step 9600: train loss 1.1818, val loss 1.4217
# step 9700: train loss 1.1841, val loss 1.4281
# step 9800: train loss 1.1821, val loss 1.4588
# step 9900: train loss 1.1783, val loss 1.4304
# step 9999: train loss 1.1747, val loss 1.4242
#
#    I will he gave I'll be with fir. I'll tell you and supposey that meant necest tonight or Father the will. Lord leyt in your hearts continue to me.  And - I with it say what I know I have has take all we're a peace. Get in my with other all of you.  Thank you ever foreveral. Irene.  My qetatired Freper: Here in your heart and what I hope that ya'll ask the Upes it.  First on off, the plater thing you have respect please dog.  Oh, I love you, love you all. I want to see on. I hope that he had. I've say I pray this even with me. I am infiend if you know me and miss. I hope so meand and I hold it's a blames in they only friend.  I wrote it's a good litten lit to thing and no giving understand children.  Don't beautipation, - a more if the law: free with me. We if I hope they years and I will be in the prisond-and no bless there are geart united fromight, Stin it in the who stings have wested. I'm done the father I walks takes up. I had nothin' Ucy off olverca. I hoped that you ill, I am guilt for it. I can statement)
#
# Yes  I'm sadding in you have meettely listles on. Statey different aswell have 6, Shorts. Ni. Storna no guilty mnever head we can give them. Thi breastity here.  God inclusion. It's glading you.  God blesy thing I love you.  Ya'll pray free, I am meart then love. I have That your heal when I know w. Sapk, then I just nied pow who contimus with a pordenty. That deserves and and begared to shood eachman here things. Now himad to felf well be in my support for the gettian me and you know that he said to who degtten.  This is ask frominity, I forgive us to confina, I have don't hate like for you and I take you.  My gun l've and family I don't the witim to forgive me, then when right.
#
#    I am going to be wish they in your heart too coveleima from the Willersarch, when I it im really y'all.  God in ya'll.  Mela, Godbye, Jack Jine - We warde us thing that I had no all magely sorry to hearts to play hellas me. I know what happened. I will pray the trugglast le
